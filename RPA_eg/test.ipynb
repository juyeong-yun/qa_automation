# %%
# !pip install selenium

# %%
from selenium import webdriver
driver = webdriver.Chrome('.chromedriver')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 from selenium import webdriver
# ----> 2 driver = webdriver.Chrome('.chromedriver')
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/selenium/webdriver/chrome/webdriver.py:47, in WebDriver.__init__(self, options, service, keep_alive)
#      44 service = service if service else Service()
#      45 options = options if options else Options()
# ---> 47 super().__init__(
#      48     browser_name=DesiredCapabilities.CHROME["browserName"],
#      49     vendor_prefix="goog",
#      50     options=options,
#      51     service=service,
#      52     keep_alive=keep_alive,
#      53 )
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/selenium/webdriver/chromium/webdriver.py:55, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
# ...
